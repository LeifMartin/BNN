# %%
import math
import seaborn as sns
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
from tensorboardX import SummaryWriter
from torchvision import datasets, transforms
from torchvision.utils import make_grid
from tqdm import tqdm, trange
import pandas as pd
import time
import mpmath
import os
import importlib
import importlib
import FVMF
importlib.reload(FVMF)
import test_ensemble
importlib.reload(test_ensemble)
import matplotlib.pyplot as plt

# define the parameters
BATCH_SIZE = 100
TEST_BATCH_SIZE = 100
COND_OPT = False
CLASSES = 10
# TRAIN_EPOCHS = 250
SAMPLES = 1
TEST_SAMPLES = 10
TEMPER = 0.001
TEMPER_PRIOR = 0.001
pepochs = 50


DEVICE = torch.device("cuda:1")
LOADER_KWARGS = {'num_workers': 1, 'pin_memory': True} if torch.cuda.is_available() else {}
cuda = torch.cuda.set_device(1)


#d_CIFAR_train = datasets.CIFAR10(root='./data', train=True, download=True, transform=transforms.ToTensor())
#d_CIFAR_test = datasets.CIFAR10(root='./data', train=False, download=True, transform=transforms.ToTensor())

#print(transforms.ToTensor(cifar_train))
#print(dtrain[0].shape)

#Ok so this is actually not trivial... Maybe we need to place a convulutional layer first in order to properly parse this into
#our vMF so that we don't lose the positionality of our data?

train_loader = torch.utils.data.DataLoader(
    datasets.EMNIST(
        './mnist', train=True, split = 'mnist', download=True,
        transform=transforms.ToTensor()),
    batch_size=6000, shuffle=True, **LOADER_KWARGS)
test_loader = torch.utils.data.DataLoader(
    datasets.EMNIST(
        './mnist', train=False, split = 'mnist', download=True,
        transform=transforms.ToTensor()),
    batch_size=10000, shuffle=False, **LOADER_KWARGS)

TRAIN_SIZE = len(train_loader.dataset)
TEST_SIZE = len(test_loader.dataset)
NUM_BATCHES = len(train_loader)
NUM_TEST_BATCHES = len(test_loader)

for batch_idx, (data, target) in enumerate(train_loader):
    train_data, train_target = data.to(DEVICE), target.to(DEVICE)
#print(train_data.shape)

for batch_idx, (data, target) in enumerate(test_loader):
    test_data, test_target = data.to(DEVICE), target.to(DEVICE)
#test_data = torch.cat

#dtrain Må pakke den inn i en dimensjon... kanskje?

print(train_data.shape,test_data.shape)
print(train_target.shape,test_target.shape)

dtrain = torch.flatten(train_data, start_dim=1, end_dim= -1)
#print(dtrain.shape)

dtest = torch.flatten(test_data, start_dim=1, end_dim= -1)
#print(dtest.shape)

#print(train_target.shape)
#dtrain = torch.cat((dtrain,train_target), dim = 0)

train_target1 = torch.reshape(train_target,(6000, 1))
#print(train_target1.shape)

dtrain = torch.cat((dtrain,train_target1), dim = 1).numpy(force=True)
print(dtrain.shape)

test_target1 = torch.reshape(test_target,(10000, 1))
#print(test_target1.shape)

dtest = torch.cat((dtest,test_target1), dim = 1).numpy(force=True)
print(dtest.shape)

l1shape=(784,10)
l2shape=(10, 10)
l3shape=(10, 10)
#l4shape=(10, 10)
#layershapes = [l1shape, l2shape, l3shape, l4shape]
layershapes = [l1shape, l2shape, l3shape]
data_shape = (0,784,784,785)

norm_w_mu_layer1 = []

import math
import seaborn as sns
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
from tensorboardX import SummaryWriter
from torchvision import datasets, transforms
from torchvision.utils import make_grid
from tqdm import tqdm, trange
import pandas as pd
import time
import mpmath
import os
import importlib
import matplotlib.pyplot as plt

import test_ensemble
importlib.reload(test_ensemble)
import FVMF
importlib.reload(FVMF)

trtimes  = []

epochs =10

for i in range(0, 1):
    print(i)
    torch.manual_seed(i)
    net5= FVMF.BayesianNetwork(#w_mu = w_mu, b_mu = b_mu, 
                                #w_mu = None, b_mu = None,
                                #w_mu = w_mu_nodewise, b_mu = b_mu,
                                layershapes = layershapes,
                                dtrain=dtrain, dtest=dtest,
                                VD='Gaussian',
                                #b_kappa=torch.Tensor(1).uniform_(3,3.1),
                                #w_kappa=torch.Tensor(1).uniform_(5,5.1),
                                Temper = 0.1,
                                classification = 'classification',VISION = 'dense')
    
    #for j,p in enumerate(net2.l1.parameters()):    
    #    p.requires_grad_(False)
    #    
    #for j,p in enumerate(net2.l2.parameters()):
    #    p.requires_grad_(False)
    
    optimizer = optim.Adam(net5.parameters(), lr=0.0007)
    
    
    for epoch in range(epochs):
        train = FVMF.train(net5, dtrain, SAMPLES, optimizer, epoch, i,BATCH_SIZE = 100,
                                    shape = data_shape,CLASSES = CLASSES)    
        trtimes.append(train[1].detach().cpu().numpy())
        #print('max:',net4.weight_mu[1].max())
        norm = 0
        for i in net5.weight_mu:
            norm+=torch.norm(i)
        #norm = norm/len(net5.weight_mu)
        norm_w_mu_layer1.append(norm.detach().cpu().numpy()/len(net5.weight_mu))

    res = test_ensemble.test_ensemble(net5,dtest,TEST_SAMPLES,TEST_BATCH_SIZE,TEST_BATCH_SIZE,
                                      CLASSES=CLASSES,DEVICE=DEVICE,shape = data_shape,plot = True)
    print('Gaussian 10 epoch')
    #np.savetxt("soundGmaccuracies_" + str(i) + ".csv", res, delimiter=",")

epochs = 20


for epoch in range(epochs):
    train = FVMF.train(net5, dtrain, SAMPLES, optimizer, epoch, i,BATCH_SIZE = 100,
                                shape = data_shape,CLASSES = CLASSES)    
    trtimes.append(train[1].detach().cpu().numpy())
    norm = 0
    for i in net5.weight_mu:
        norm+=torch.norm(i)
    #norm = norm/len(net5.weight_mu)
    norm_w_mu_layer1.append(norm.detach().cpu().numpy()/len(net5.weight_mu))
#print('norm:',torch.norm(net4.weight_mu[1]))

res = test_ensemble.test_ensemble(net5,dtest,TEST_SAMPLES,TEST_BATCH_SIZE,TEST_BATCH_SIZE,
                                  CLASSES,DEVICE,shape = data_shape,plot = True)
print('Gaussian 30 epoch')

epochs = 20

for epoch in range(epochs):
    train = FVMF.train(net5, dtrain, SAMPLES, optimizer, epoch, i,BATCH_SIZE = 100,
                                shape = data_shape,CLASSES = CLASSES)    
    trtimes.append(train[1].detach().cpu().numpy())
    #print('max:',net4.weight_mu[1].max())
    norm = 0
    for i in net5.weight_mu:
        norm+=torch.norm(i)
    #norm = norm/len(net5.weight_mu)
    norm_w_mu_layer1.append(norm.detach().cpu().numpy()/len(net5.weight_mu))
    
res = test_ensemble.test_ensemble(net5,dtest,TEST_SAMPLES,TEST_BATCH_SIZE,TEST_BATCH_SIZE,
                                  CLASSES,DEVICE,shape = data_shape,plot = True)
print('Gaussian 50 epoch')

x = []
for i in range(50):
    x.append(i+1)
print('Gaussian loss curve, 50 epoch QVision')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.plot(x,trtimes)
plt.savefig('Plots/Gaussian_loss_50_epoch_QVision.png', dpi=250)
plt.show()

x = []
for i in range(50):
    x.append(i+1)
print('Gaussian weight average mu norm per epoch')
plt.xlabel('Epoch')
plt.ylabel('Norm')
plt.plot(x,norm_w_mu_layer1)
plt.savefig('Plots/Gaussian_norm_50_epoch_QVision.png', dpi=250)
plt.show()

norm_w_mu_layer1 = []
trtimes  = []
epochs = 30

#Note, for this regression task, the last 7 to 1 layer has a Gaussian VD, where we kill the prior and simply optimize with MLE.
for i in range(0, 1):
    print(i)
    torch.manual_seed(i)
    vMFRegression30= FVMF.BayesianNetwork(#w_mu = w_mu, b_mu = b_mu, 
                                #w_mu = None, b_mu = None,
                                #w_mu = w_mu_nodewise, b_mu = b_mu,
                                layershapes = layershapes,
                                dtrain=dtrain, dtest=dtest,
                                VD='vmf',
                                b_kappa=torch.Tensor(1).uniform_(3,3.1),
                                w_kappa=torch.Tensor(1).uniform_(6.5,6.6),
                                Temper = 0,classification = 'classification',VISION = 'dense')
    
    #for j,p in enumerate(net2.l1.parameters()):
    #    p.requires_grad_(False)
    #    
    #for j,p in enumerate(net2.l2.parameters()):
    #    p.requires_grad_(False)
    
    optimizer = optim.Adam(vMFRegression30.parameters(), lr=0.08)
    
    
    for epoch in range(epochs):
        train = FVMF.train(vMFRegression30, dtrain, SAMPLES, optimizer, epoch, i,BATCH_SIZE = 100,
                                    shape = data_shape,CLASSES = CLASSES)    
        trtimes.append(train[1].detach().cpu().numpy())
        #print('max:',vMFRegression30.weight_mu[1].max())
        norm = 0
        for i in vMFRegression30.weight_mu:
            norm+=torch.norm(i)
        #norm = norm/len(net5.weight_mu)
        norm_w_mu_layer1.append(norm.detach().cpu().numpy()/len(vMFRegression30.weight_mu))
    res = test_ensemble.test_ensemble(vMFRegression30,dtest,TEST_SAMPLES,TEST_BATCH_SIZE,TEST_BATCH_SIZE,
                                      CLASSES,DEVICE,shape = data_shape,plot = True)
    print('vMF 30 epoch')

epochs = 20


for epoch in range(epochs):
    train = FVMF.train(vMFRegression30, dtrain, SAMPLES, optimizer, epoch, i,BATCH_SIZE = 100,
                                shape = data_shape,CLASSES = CLASSES)    
    trtimes.append(train[1].detach().cpu().numpy())
    #print('max:',vMFRegression30.weight_mu[1].max())
    norm = 0
    for i in vMFRegression30.weight_mu:
        norm+=torch.norm(i)
    #norm = norm/len(net5.weight_mu)
    norm_w_mu_layer1.append(norm.detach().cpu().numpy()/len(vMFRegression30.weight_mu))
res = test_ensemble.test_ensemble(vMFRegression30,dtest,TEST_SAMPLES,TEST_BATCH_SIZE,TEST_BATCH_SIZE,
                                  CLASSES,DEVICE,shape = data_shape,plot = True)
print('vMF 50 epoch')

x = []
for i in range(50):
    x.append(i+1)
print('vMF loss curve, 50 epoch regression')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.plot(x,trtimes)
plt.savefig('Plots/vMF_loss_50_epoch_QVision.png', dpi=250)
plt.show()

x = []
for i in range(50):
    x.append(i+1)
print('vMF weight mu average norm per epoch')
plt.xlabel('Epoch')
plt.ylabel('Norm')
plt.plot(x,norm_w_mu_layer1)
plt.savefig('Plots/vMF_norm_50_epoch_QVision.png', dpi=250)
plt.show()

norm_w_mu_layer1 = []

import math
import seaborn as sns
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
from tensorboardX import SummaryWriter
from torchvision import datasets, transforms
from torchvision.utils import make_grid
from tqdm import tqdm, trange
import pandas as pd
import time
import mpmath
import os
import importlib
import matplotlib.pyplot as plt

# define the parameters
BATCH_SIZE = 100
TEST_BATCH_SIZE = 100
COND_OPT = False
CLASSES = 10
# TRAIN_EPOCHS = 250
SAMPLES = 1
TEST_SAMPLES = 10
TEMPER = 0.001
TEMPER_PRIOR = 0.001
pepochs = 50

import test_ensemble
importlib.reload(test_ensemble)
import FVMF
importlib.reload(FVMF)

epochs = 10
trtimes = []


for i in range(0, 1):
    print(i)
    torch.manual_seed(i)
    vMFRegression= FVMF.BayesianNetwork(#w_mu = w_mu, b_mu = b_mu, 
                                #w_mu = None, b_mu = None,
                                #w_mu = w_mu_nodewise, b_mu = b_mu,
                                layershapes = layershapes,
                                dtrain=dtrain, dtest=dtest,
                                VD='vmf',
                                b_kappa=torch.Tensor(1).uniform_(3,3.1),
                                w_kappa=torch.Tensor(1).uniform_(6.5,6.6),
                                Temper = 0,classification = 'classification',VISION = 'dense',NODEFORCE =False)
    
    #for j,p in enumerate(net2.l1.parameters()):
    #    p.requires_grad_(False)
    #    
    #for j,p in enumerate(net2.l2.parameters()):
    #    p.requires_grad_(False)
    
    optimizer = optim.Adam(vMFRegression.parameters(), lr=0.10) #0.11
    
    
    for epoch in range(epochs):
        train = FVMF.train(vMFRegression, dtrain, SAMPLES, optimizer, epoch, i,BATCH_SIZE = 100,
                                    shape = data_shape,CLASSES = CLASSES)    
        trtimes.append(train[1].detach().cpu().numpy())
        #print('max:',vMFRegression.weight_mu[1].max())
        norm = 0
        for i in vMFRegression.weight_mu:
            norm+=torch.norm(i)
        #norm = norm/len(net5.weight_mu)
        norm_w_mu_layer1.append(norm.detach().cpu().numpy()/len(vMFRegression.weight_mu))
    res = test_ensemble.test_ensemble(vMFRegression,dtest,TEST_SAMPLES,TEST_BATCH_SIZE,TEST_BATCH_SIZE,
                                      CLASSES,DEVICE,shape = data_shape,plot = True)
    print('vMF 10 epoch')
    #np.savetxt("soundGmaccuracies_" + str(i) + ".csv", res, delimiter=",")

GC_intensity = 1

#Kanskje er det en god idee å også arve kappaene, men halvere dem? Hva om vi også kjører på med litt normalizering av mu-ene her?
#Hva med adaptiv kappa per lag? Det er jo bare en kappa per bias-lag. GC fungerer rett og slett ikke.

w_mu_R = []
for i in range(len(vMFRegression.weight_mu)):
    #print('\n','torch.norm(net4.weight_mu[i]):',torch.norm(net4.weight_mu[i]))
    w_mu_R.append(vMFRegression.weight_mu[i]/torch.norm(vMFRegression.weight_mu[i]))
    #print('\n','norm w_mu[i]',torch.norm(w_mu[i]))
    
b_mu_R = []
for i in range(len(vMFRegression.bias_mu)):
    #print('\n','torch.norm(net4.bais_mu[i]):',torch.norm(net4.bias_mu[i]))
    b_mu_R.append(vMFRegression.bias_mu[i]/torch.norm(vMFRegression.bias_mu[i]))
    #print('\n','norm b_mu[i]',torch.norm(b_mu[i]))
    
b_rho_R= []
for i in range(len(vMFRegression.bias_rho)):
    b_rho_R.append(vMFRegression.bias_rho[i])

w_rho_R= []
for i in range(len(vMFRegression.weight_rho)):
    w_rho_R.append(vMFRegression.weight_rho[i])
#For some reason, it seems that the weights are not being properly normalized here. no actually they are, but the norm reported is the norm after 1 optimization step.

epochs = 20
for i in range(0, 1):
    print(i)
    torch.manual_seed(i)
    vMFRegression2= FVMF.BayesianNetwork(w_mu = w_mu_R, b_mu = b_mu_R, 
                                #w_mu = None, b_mu = None,
                                #w_mu = w_mu_nodewise, b_mu = b_mu,
                                layershapes = layershapes,
                                dtrain=dtrain, dtest=dtest,
                                VD='vmf',
                                b_kappa= b_rho_R, #torch.Tensor(1).uniform_(1.0,3.1), 
                                w_kappa= w_rho_R, #torch.Tensor(1).uniform_(2.0,4.1), 
                                Temper = 0,classification = 'classification',VISION = 'dense')
    
    
    optimizer = optim.Adam(vMFRegression2.parameters(), lr=0.025) #0.01 9727 acc
    
    
    for epoch in range(epochs):
        train = FVMF.train(vMFRegression2, dtrain, SAMPLES, optimizer, epoch, i,BATCH_SIZE = 100,
                                    shape = data_shape,CLASSES = CLASSES)    
        trtimes.append(train[1].detach().cpu().numpy())
        print('max:',vMFRegression2.weight_mu[1].max())
        norm = 0
        for i in vMFRegression2.weight_mu:
            norm+=torch.norm(i)
        #norm = norm/len(net5.weight_mu)
        norm_w_mu_layer1.append(norm.detach().cpu().numpy()/len(vMFRegression2.weight_mu))

    res = test_ensemble.test_ensemble(vMFRegression2,dtest,TEST_SAMPLES,TEST_BATCH_SIZE,TEST_BATCH_SIZE,
                                      CLASSES,DEVICE,shape = data_shape,plot = True)
    print('vMF 10+20 epoch NII')

#Kanskje er det en god idee å også arve kappaene, men halvere dem? Hva om vi også kjører på med litt normalizering av mu-ene her?
#Hva med adaptiv kappa per lag? Det er jo bare en kappa per bias-lag. GC fungerer rett og slett ikke.

w_mu_R = []
for i in range(len(vMFRegression2.weight_mu)):
    #print('\n','torch.norm(net4.weight_mu[i]):',torch.norm(net4.weight_mu[i]))
    w_mu_R.append(vMFRegression2.weight_mu[i]/torch.norm(vMFRegression2.weight_mu[i]))
    #print('\n','norm w_mu[i]',torch.norm(w_mu[i]))
    
b_mu_R = []
for i in range(len(vMFRegression2.bias_mu)):
    #print('\n','torch.norm(net4.bais_mu[i]):',torch.norm(net4.bias_mu[i]))
    b_mu_R.append(vMFRegression2.bias_mu[i]/torch.norm(vMFRegression2.bias_mu[i]))
    #print('\n','norm b_mu[i]',torch.norm(b_mu[i]))
    
b_rho_R= []
for i in range(len(vMFRegression2.bias_rho)):
    b_rho_R.append(vMFRegression2.bias_rho[i])

w_rho_R= []
for i in range(len(vMFRegression2.weight_rho)):
    w_rho_R.append(vMFRegression2.weight_rho[i])
#For some reason, it seems that the weights are not being properly normalized here. no actually they are, but the norm reported is the norm after 1 optimization step.

epochs = 20
for i in range(0, 1):
    print(i)
    torch.manual_seed(i)
    vMFRegression3= FVMF.BayesianNetwork(w_mu = w_mu_R, b_mu = b_mu_R, 
                                #w_mu = None, b_mu = None,
                                #w_mu = w_mu_nodewise, b_mu = b_mu,
                                layershapes = layershapes,
                                dtrain=dtrain, dtest=dtest,
                                VD='vmf',
                                b_kappa= b_rho_R, #torch.Tensor(1).uniform_(1.0,3.1), 
                                w_kappa= w_rho_R, #torch.Tensor(1).uniform_(2.0,4.1), 
                                Temper = 0,classification = 'classification',VISION = 'dense')
    
    #for j,p in enumerate(net2.l1.parameters()):
    #    p.requires_grad_(False)
    #    
    #for j,p in enumerate(net2.l2.parameters()):
    #    p.requires_grad_(False)
    
    optimizer = optim.Adam(vMFRegression3.parameters(), lr=0.01) #0.01 9083/10000 acc
    
    
    for epoch in range(epochs):
        train = FVMF.train(vMFRegression3, dtrain, SAMPLES, optimizer, epoch, i,BATCH_SIZE = 100,
                                    shape = data_shape,CLASSES = CLASSES)
        trtimes.append(train[1].detach().cpu().numpy())
        #print('max:',vMFRegression3.weight_mu[1].max())
        norm = 0
        for i in vMFRegression3.weight_mu:
            norm+=torch.norm(i)
        #norm = norm/len(net5.weight_mu)
        norm_w_mu_layer1.append(norm.detach().cpu().numpy()/len(vMFRegression3.weight_mu))
    res = test_ensemble.test_ensemble(vMFRegression3,dtest,TEST_SAMPLES,TEST_BATCH_SIZE,TEST_BATCH_SIZE,
                                      CLASSES,DEVICE,shape = data_shape,plot = True)
    print('vMF 10+20+20 epoch NII')

x = []
for i in range(50):
    x.append(i+1)
print('NIIvMF loss curve, 50 epoch Vision')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.plot(x,trtimes)
plt.savefig('Plots/NIIvMF_loss_50_epoch_QVision.png', dpi=250)
plt.show()

x = []
for i in range(50):
    x.append(i+1)
print('NIIvMF weight mu average norm per epoch Vision')
plt.xlabel('Epoch')
plt.ylabel('Norm')
plt.plot(x,norm_w_mu_layer1)
plt.savefig('Plots/NIIvMF_norm_50_epoch_QVision.png', dpi=250)
plt.show()
# Out:
# GPUs are used!
# FVMF RELOADED
# torch.Size([6000, 1, 28, 28]) torch.Size([10000, 1, 28, 28])
# torch.Size([6000]) torch.Size([10000])
# (6000, 785)
# (10000, 785)
# GPUs are used!
# FVMF RELOADED
# 0
# Random Init Utilized
# oui
# /opt/uio/modules/rhel8/easybuild/software/Miniconda3/lmsunde/envs/BNN2/lib/python3.10/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# 1
# loss: tensor(220.8559, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(219.4106, device='cuda:1', grad_fn=<NllLossBackward0>)
# 2
# loss: tensor(192.2031, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(190.7610, device='cuda:1', grad_fn=<NllLossBackward0>)
# 3
# loss: tensor(148.4785, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(147.0401, device='cuda:1', grad_fn=<NllLossBackward0>)
# 4
# loss: tensor(102.4221, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(100.9797, device='cuda:1', grad_fn=<NllLossBackward0>)
# 5
# loss: tensor(81.2721, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(79.8491, device='cuda:1', grad_fn=<NllLossBackward0>)
# 6
# loss: tensor(69.3640, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(67.8966, device='cuda:1', grad_fn=<NllLossBackward0>)
# 7
# loss: tensor(65.4769, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(64.0488, device='cuda:1', grad_fn=<NllLossBackward0>)
# 8
# loss: tensor(59.9683, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(58.5226, device='cuda:1', grad_fn=<NllLossBackward0>)
# 9
# loss: tensor(57.0048, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(55.5531, device='cuda:1', grad_fn=<NllLossBackward0>)
# 10
# loss: tensor(55.2211, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(53.7967, device='cuda:1', grad_fn=<NllLossBackward0>)
# Component 0 Accuracy: 8702.0/10000
# Component 1 Accuracy: 8692.0/10000
# Component 2 Accuracy: 8730.0/10000
# Component 3 Accuracy: 8699.0/10000
# Component 4 Accuracy: 8676.0/10000
# Component 5 Accuracy: 8708.0/10000
# Component 6 Accuracy: 8709.0/10000
# Component 7 Accuracy: 8686.0/10000
# Component 8 Accuracy: 8697.0/10000
# Component 9 Accuracy: 8701.0/10000
# Posterior Mean Accuracy: 8761.0/10000
# Ensemble Accuracy: 8748/10000
# Gaussian 10 epoch
# 1
# loss: tensor(50.1598, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(50.1598, device='cuda:1', grad_fn=<NllLossBackward0>)
# 2
# loss: tensor(48.7401, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(48.7401, device='cuda:1', grad_fn=<NllLossBackward0>)
# 3
# loss: tensor(45.8148, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(45.8148, device='cuda:1', grad_fn=<NllLossBackward0>)
# 4
# loss: tensor(47.9501, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(47.9501, device='cuda:1', grad_fn=<NllLossBackward0>)
# 5
# loss: tensor(46.6622, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(46.6622, device='cuda:1', grad_fn=<NllLossBackward0>)
# 6
# loss: tensor(49.0136, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(49.0136, device='cuda:1', grad_fn=<NllLossBackward0>)
# 7
# loss: tensor(44.0947, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(44.0947, device='cuda:1', grad_fn=<NllLossBackward0>)
# 8
# loss: tensor(41.5340, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(41.5340, device='cuda:1', grad_fn=<NllLossBackward0>)
# 9
# loss: tensor(42.5743, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(42.5743, device='cuda:1', grad_fn=<NllLossBackward0>)
# 10
# loss: tensor(43.3888, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(43.3888, device='cuda:1', grad_fn=<NllLossBackward0>)
# 11
# loss: tensor(42.4077, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(42.4077, device='cuda:1', grad_fn=<NllLossBackward0>)
# 12
# loss: tensor(44.1220, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(44.1220, device='cuda:1', grad_fn=<NllLossBackward0>)
# 13
# loss: tensor(42.6406, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(42.6406, device='cuda:1', grad_fn=<NllLossBackward0>)
# 14
# loss: tensor(41.0865, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(41.0865, device='cuda:1', grad_fn=<NllLossBackward0>)
# 15
# loss: tensor(36.8242, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(36.8242, device='cuda:1', grad_fn=<NllLossBackward0>)
# 16
# loss: tensor(39.4498, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(39.4498, device='cuda:1', grad_fn=<NllLossBackward0>)
# 17
# loss: tensor(40.2293, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(40.2293, device='cuda:1', grad_fn=<NllLossBackward0>)
# 18
# loss: tensor(38.9533, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(38.9533, device='cuda:1', grad_fn=<NllLossBackward0>)
# 19
# loss: tensor(44.4525, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(44.4525, device='cuda:1', grad_fn=<NllLossBackward0>)
# 20
# loss: tensor(39.3680, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(39.3680, device='cuda:1', grad_fn=<NllLossBackward0>)
# Component 0 Accuracy: 9070.0/10000
# Component 1 Accuracy: 9091.0/10000
# Component 2 Accuracy: 9064.0/10000
# Component 3 Accuracy: 9067.0/10000
# Component 4 Accuracy: 9052.0/10000
# Component 5 Accuracy: 9073.0/10000
# Component 6 Accuracy: 9077.0/10000
# Component 7 Accuracy: 9087.0/10000
# Component 8 Accuracy: 9069.0/10000
# Component 9 Accuracy: 9064.0/10000
# Posterior Mean Accuracy: 9103.0/10000
# Ensemble Accuracy: 9097/10000
# Gaussian 30 epoch
# 1
# loss: tensor(39.0427, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(39.0427, device='cuda:1', grad_fn=<NllLossBackward0>)
# 2
# loss: tensor(37.1193, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(37.1193, device='cuda:1', grad_fn=<NllLossBackward0>)
# 3
# loss: tensor(41.8004, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(41.8004, device='cuda:1', grad_fn=<NllLossBackward0>)
# 4
# loss: tensor(38.5913, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(38.5913, device='cuda:1', grad_fn=<NllLossBackward0>)
# 5
# loss: tensor(38.1802, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(38.1802, device='cuda:1', grad_fn=<NllLossBackward0>)
# 6
# loss: tensor(32.0371, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(32.0371, device='cuda:1', grad_fn=<NllLossBackward0>)
# 7
# loss: tensor(36.6793, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(36.6793, device='cuda:1', grad_fn=<NllLossBackward0>)
# 8
# loss: tensor(36.3706, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(36.3706, device='cuda:1', grad_fn=<NllLossBackward0>)
# 9
# loss: tensor(38.0962, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(38.0962, device='cuda:1', grad_fn=<NllLossBackward0>)
# 10
# loss: tensor(34.2540, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(34.2540, device='cuda:1', grad_fn=<NllLossBackward0>)
# 11
# loss: tensor(31.8293, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(31.8293, device='cuda:1', grad_fn=<NllLossBackward0>)
# 12
# loss: tensor(31.4258, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(31.4258, device='cuda:1', grad_fn=<NllLossBackward0>)
# 13
# loss: tensor(35.9712, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(35.9712, device='cuda:1', grad_fn=<NllLossBackward0>)
# 14
# loss: tensor(31.9938, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(31.9938, device='cuda:1', grad_fn=<NllLossBackward0>)
# 15
# loss: tensor(29.4118, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(29.4118, device='cuda:1', grad_fn=<NllLossBackward0>)
# 16
# loss: tensor(32.2490, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(32.2490, device='cuda:1', grad_fn=<NllLossBackward0>)
# 17
# loss: tensor(30.4189, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(30.4189, device='cuda:1', grad_fn=<NllLossBackward0>)
# 18
# loss: tensor(30.6373, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(30.6373, device='cuda:1', grad_fn=<NllLossBackward0>)
# 19
# loss: tensor(31.4307, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(31.4307, device='cuda:1', grad_fn=<NllLossBackward0>)
# 20
# loss: tensor(30.2748, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(30.2748, device='cuda:1', grad_fn=<NllLossBackward0>)
# Component 0 Accuracy: 9161.0/10000
# Component 1 Accuracy: 9171.0/10000
# Component 2 Accuracy: 9158.0/10000
# Component 3 Accuracy: 9156.0/10000
# Component 4 Accuracy: 9165.0/10000
# Component 5 Accuracy: 9157.0/10000
# Component 6 Accuracy: 9157.0/10000
# Component 7 Accuracy: 9158.0/10000
# Component 8 Accuracy: 9177.0/10000
# Component 9 Accuracy: 9181.0/10000
# Posterior Mean Accuracy: 9182.0/10000
# Ensemble Accuracy: 9172/10000
# Gaussian 50 epoch
# Gaussian loss curve, 50 epoch QVision
# Gaussian weight average mu norm per epoch
# 0
# Random Init Utilized
# oui
# 1
# loss: tensor(247.6194, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(247.6194, device='cuda:1', grad_fn=<NllLossBackward0>)
# 2
# loss: tensor(165.8455, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(165.8455, device='cuda:1', grad_fn=<NllLossBackward0>)
# 3
# loss: tensor(129.1650, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(129.1650, device='cuda:1', grad_fn=<NllLossBackward0>)
# 4
# loss: tensor(151.3347, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(151.3347, device='cuda:1', grad_fn=<NllLossBackward0>)
# 5
# loss: tensor(118.5690, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(118.5690, device='cuda:1', grad_fn=<NllLossBackward0>)
# 6
# loss: tensor(159.3219, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(159.3219, device='cuda:1', grad_fn=<NllLossBackward0>)
# 7
# loss: tensor(121.4663, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(121.4663, device='cuda:1', grad_fn=<NllLossBackward0>)
# 8
# loss: tensor(110.5129, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(110.5129, device='cuda:1', grad_fn=<NllLossBackward0>)
# 9
# loss: tensor(105.2862, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(105.2862, device='cuda:1', grad_fn=<NllLossBackward0>)
# 10
# loss: tensor(113.0506, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(113.0506, device='cuda:1', grad_fn=<NllLossBackward0>)
# 11
# loss: tensor(104.6984, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(104.6984, device='cuda:1', grad_fn=<NllLossBackward0>)
# 12
# loss: tensor(74.1110, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(74.1110, device='cuda:1', grad_fn=<NllLossBackward0>)
# 13
# loss: tensor(96.2623, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(96.2623, device='cuda:1', grad_fn=<NllLossBackward0>)
# 14
# loss: tensor(75.8283, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(75.8283, device='cuda:1', grad_fn=<NllLossBackward0>)
# 15
# loss: tensor(80.3237, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(80.3237, device='cuda:1', grad_fn=<NllLossBackward0>)
# 16
# loss: tensor(76.4156, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(76.4156, device='cuda:1', grad_fn=<NllLossBackward0>)
# 17
# loss: tensor(69.3181, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(69.3181, device='cuda:1', grad_fn=<NllLossBackward0>)
# 18
# loss: tensor(72.6924, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(72.6924, device='cuda:1', grad_fn=<NllLossBackward0>)
# 19
# loss: tensor(99.3312, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(99.3312, device='cuda:1', grad_fn=<NllLossBackward0>)
# 20
# loss: tensor(126.9744, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(126.9744, device='cuda:1', grad_fn=<NllLossBackward0>)
# 21
# loss: tensor(60.9001, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(60.9001, device='cuda:1', grad_fn=<NllLossBackward0>)
# 22
# loss: tensor(84.7217, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(84.7217, device='cuda:1', grad_fn=<NllLossBackward0>)
# 23
# loss: tensor(64.1300, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(64.1300, device='cuda:1', grad_fn=<NllLossBackward0>)
# 24
# loss: tensor(65.1710, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(65.1710, device='cuda:1', grad_fn=<NllLossBackward0>)
# 25
# loss: tensor(81.3398, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(81.3398, device='cuda:1', grad_fn=<NllLossBackward0>)
# 26
# loss: tensor(60.1830, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(60.1830, device='cuda:1', grad_fn=<NllLossBackward0>)
# 27
# loss: tensor(60.8524, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(60.8524, device='cuda:1', grad_fn=<NllLossBackward0>)
# 28
# loss: tensor(52.9607, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(52.9607, device='cuda:1', grad_fn=<NllLossBackward0>)
# 29
# loss: tensor(50.3162, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(50.3162, device='cuda:1', grad_fn=<NllLossBackward0>)
# 30
# loss: tensor(61.3555, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(61.3555, device='cuda:1', grad_fn=<NllLossBackward0>)
# /uio/hume/student-u44/lmsunde/projects/BNN/test_ensemble.py:17: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp(-x)))
# Component 0 Accuracy: 8341.0/10000
# Component 1 Accuracy: 8361.0/10000
# Component 2 Accuracy: 8337.0/10000
# Component 3 Accuracy: 8367.0/10000
# Component 4 Accuracy: 8245.0/10000
# Component 5 Accuracy: 8348.0/10000
# Component 6 Accuracy: 8326.0/10000
# Component 7 Accuracy: 8350.0/10000
# Component 8 Accuracy: 8346.0/10000
# Component 9 Accuracy: 8334.0/10000
# Posterior Mean Accuracy: 8615.0/10000
# Ensemble Accuracy: 8576/10000
# vMF 30 epoch
# 1
# loss: tensor(51.3756, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(51.3756, device='cuda:1', grad_fn=<NllLossBackward0>)
# 2
# loss: tensor(64.4771, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(64.4771, device='cuda:1', grad_fn=<NllLossBackward0>)
# 3
# loss: tensor(59.0197, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(59.0197, device='cuda:1', grad_fn=<NllLossBackward0>)
# 4
# loss: tensor(52.0569, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(52.0569, device='cuda:1', grad_fn=<NllLossBackward0>)
# 5
# loss: tensor(41.5949, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(41.5949, device='cuda:1', grad_fn=<NllLossBackward0>)
# 6
# loss: tensor(50.3291, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(50.3291, device='cuda:1', grad_fn=<NllLossBackward0>)
# 7
# loss: tensor(69.0697, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(69.0697, device='cuda:1', grad_fn=<NllLossBackward0>)
# 8
# loss: tensor(64.1469, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(64.1469, device='cuda:1', grad_fn=<NllLossBackward0>)
# 9
# loss: tensor(81.8115, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(81.8115, device='cuda:1', grad_fn=<NllLossBackward0>)
# 10
# loss: tensor(45.8986, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(45.8986, device='cuda:1', grad_fn=<NllLossBackward0>)
# 11
# loss: tensor(70.3081, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(70.3081, device='cuda:1', grad_fn=<NllLossBackward0>)
# 12
# loss: tensor(43.8116, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(43.8116, device='cuda:1', grad_fn=<NllLossBackward0>)
# 13
# loss: tensor(42.5449, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(42.5449, device='cuda:1', grad_fn=<NllLossBackward0>)
# 14
# loss: tensor(33.3307, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(33.3307, device='cuda:1', grad_fn=<NllLossBackward0>)
# 15
# loss: tensor(58.0234, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(58.0234, device='cuda:1', grad_fn=<NllLossBackward0>)
# 16
# loss: tensor(35.7987, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(35.7987, device='cuda:1', grad_fn=<NllLossBackward0>)
# 17
# loss: tensor(48.4576, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(48.4576, device='cuda:1', grad_fn=<NllLossBackward0>)
# 18
# loss: tensor(60.0096, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(60.0096, device='cuda:1', grad_fn=<NllLossBackward0>)
# 19
# loss: tensor(38.4970, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(38.4970, device='cuda:1', grad_fn=<NllLossBackward0>)
# 20
# loss: tensor(51.7659, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(51.7659, device='cuda:1', grad_fn=<NllLossBackward0>)
# Component 0 Accuracy: 8535.0/10000
# Component 1 Accuracy: 8568.0/10000
# Component 2 Accuracy: 8531.0/10000
# Component 3 Accuracy: 8544.0/10000
# Component 4 Accuracy: 8566.0/10000
# Component 5 Accuracy: 8558.0/10000
# Component 6 Accuracy: 8568.0/10000
# Component 7 Accuracy: 8551.0/10000
# Component 8 Accuracy: 8571.0/10000
# Component 9 Accuracy: 8577.0/10000
# Posterior Mean Accuracy: 8759.0/10000
# Ensemble Accuracy: 8742/10000
# vMF 50 epoch
# vMF loss curve, 50 epoch regression
# vMF weight mu average norm per epoch
# GPUs are used!
# FVMF RELOADED
# 0
# Random Init Utilized
# oui
# 1
# loss: tensor(215.7031, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(215.7031, device='cuda:1', grad_fn=<NllLossBackward0>)
# 2
# loss: tensor(175.0120, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(175.0120, device='cuda:1', grad_fn=<NllLossBackward0>)
# 3
# loss: tensor(168.5063, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(168.5063, device='cuda:1', grad_fn=<NllLossBackward0>)
# 4
# loss: tensor(144.3024, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(144.3024, device='cuda:1', grad_fn=<NllLossBackward0>)
# 5
# loss: tensor(153.1439, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(153.1439, device='cuda:1', grad_fn=<NllLossBackward0>)
# 6
# loss: tensor(154.9286, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(154.9286, device='cuda:1', grad_fn=<NllLossBackward0>)
# 7
# loss: tensor(133.3754, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(133.3754, device='cuda:1', grad_fn=<NllLossBackward0>)
# 8
# loss: tensor(113.0899, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(113.0899, device='cuda:1', grad_fn=<NllLossBackward0>)
# 9
# loss: tensor(112.1094, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(112.1094, device='cuda:1', grad_fn=<NllLossBackward0>)
# 10
# loss: tensor(109.0661, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(109.0661, device='cuda:1', grad_fn=<NllLossBackward0>)
# Component 0 Accuracy: 6725.0/10000
# Component 1 Accuracy: 6733.0/10000
# Component 2 Accuracy: 6715.0/10000
# Component 3 Accuracy: 6704.0/10000
# Component 4 Accuracy: 6715.0/10000
# Component 5 Accuracy: 6741.0/10000
# Component 6 Accuracy: 6764.0/10000
# Component 7 Accuracy: 6731.0/10000
# Component 8 Accuracy: 6703.0/10000
# Component 9 Accuracy: 6734.0/10000
# Posterior Mean Accuracy: 7128.0/10000
# Ensemble Accuracy: 6994/10000
# vMF 10 epoch
# 0
# oui
# 1
# loss: tensor(125.1769, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(125.1769, device='cuda:1', grad_fn=<NllLossBackward0>)
# max: tensor(0.2785, device='cuda:1', grad_fn=<MaxBackward1>)
# 2
# loss: tensor(78.0383, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(78.0383, device='cuda:1', grad_fn=<NllLossBackward0>)
# max: tensor(0.8487, device='cuda:1', grad_fn=<MaxBackward1>)
# 3
# loss: tensor(69.4295, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(69.4295, device='cuda:1', grad_fn=<NllLossBackward0>)
# max: tensor(1.0094, device='cuda:1', grad_fn=<MaxBackward1>)
# 4
# loss: tensor(63.2489, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(63.2489, device='cuda:1', grad_fn=<NllLossBackward0>)
# max: tensor(1.0044, device='cuda:1', grad_fn=<MaxBackward1>)
# 5
# loss: tensor(51.8167, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(51.8167, device='cuda:1', grad_fn=<NllLossBackward0>)
# max: tensor(0.9843, device='cuda:1', grad_fn=<MaxBackward1>)
# 6
# loss: tensor(61.7307, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(61.7307, device='cuda:1', grad_fn=<NllLossBackward0>)
# max: tensor(1.0477, device='cuda:1', grad_fn=<MaxBackward1>)
# 7
# loss: tensor(59.9874, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(59.9874, device='cuda:1', grad_fn=<NllLossBackward0>)
# max: tensor(1.0150, device='cuda:1', grad_fn=<MaxBackward1>)
# 8
# loss: tensor(47.1915, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(47.1915, device='cuda:1', grad_fn=<NllLossBackward0>)
# max: tensor(1.0504, device='cuda:1', grad_fn=<MaxBackward1>)
# 9
# loss: tensor(49.7168, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(49.7168, device='cuda:1', grad_fn=<NllLossBackward0>)
# max: tensor(1.0475, device='cuda:1', grad_fn=<MaxBackward1>)
# 10
# loss: tensor(43.0936, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(43.0936, device='cuda:1', grad_fn=<NllLossBackward0>)
# max: tensor(1.0433, device='cuda:1', grad_fn=<MaxBackward1>)
# 11
# loss: tensor(37.1441, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(37.1441, device='cuda:1', grad_fn=<NllLossBackward0>)
# max: tensor(1.0734, device='cuda:1', grad_fn=<MaxBackward1>)
# 12
# loss: tensor(40.0271, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(40.0271, device='cuda:1', grad_fn=<NllLossBackward0>)
# max: tensor(1.0918, device='cuda:1', grad_fn=<MaxBackward1>)
# 13
# loss: tensor(51.3408, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(51.3408, device='cuda:1', grad_fn=<NllLossBackward0>)
# max: tensor(1.1514, device='cuda:1', grad_fn=<MaxBackward1>)
# 14
# loss: tensor(51.8696, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(51.8696, device='cuda:1', grad_fn=<NllLossBackward0>)
# max: tensor(1.2502, device='cuda:1', grad_fn=<MaxBackward1>)
# 15
# loss: tensor(38.8816, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(38.8816, device='cuda:1', grad_fn=<NllLossBackward0>)
# max: tensor(1.2553, device='cuda:1', grad_fn=<MaxBackward1>)
# 16
# loss: tensor(48.4686, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(48.4686, device='cuda:1', grad_fn=<NllLossBackward0>)
# max: tensor(1.2731, device='cuda:1', grad_fn=<MaxBackward1>)
# 17
# loss: tensor(28.2108, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(28.2108, device='cuda:1', grad_fn=<NllLossBackward0>)
# max: tensor(1.2097, device='cuda:1', grad_fn=<MaxBackward1>)
# 18
# loss: tensor(29.4307, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(29.4307, device='cuda:1', grad_fn=<NllLossBackward0>)
# max: tensor(1.3329, device='cuda:1', grad_fn=<MaxBackward1>)
# 19
# loss: tensor(34.8801, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(34.8801, device='cuda:1', grad_fn=<NllLossBackward0>)
# max: tensor(1.3958, device='cuda:1', grad_fn=<MaxBackward1>)
# 20
# loss: tensor(33.6796, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(33.6796, device='cuda:1', grad_fn=<NllLossBackward0>)
# max: tensor(1.4045, device='cuda:1', grad_fn=<MaxBackward1>)
# Component 0 Accuracy: 9003.0/10000
# Component 1 Accuracy: 8985.0/10000
# Component 2 Accuracy: 9003.0/10000
# Component 3 Accuracy: 8968.0/10000
# Component 4 Accuracy: 9004.0/10000
# Component 5 Accuracy: 9004.0/10000
# Component 6 Accuracy: 8956.0/10000
# Component 7 Accuracy: 8979.0/10000
# Component 8 Accuracy: 8976.0/10000
# Component 9 Accuracy: 8988.0/10000
# Posterior Mean Accuracy: 9073.0/10000
# Ensemble Accuracy: 9063/10000
# vMF 10+20 epoch NII
# 0
# oui
# 1
# loss: tensor(64.3319, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(64.3319, device='cuda:1', grad_fn=<NllLossBackward0>)
# 2
# loss: tensor(60.8611, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(60.8611, device='cuda:1', grad_fn=<NllLossBackward0>)
# 3
# loss: tensor(53.1352, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(53.1352, device='cuda:1', grad_fn=<NllLossBackward0>)
# 4
# loss: tensor(45.1853, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(45.1853, device='cuda:1', grad_fn=<NllLossBackward0>)
# 5
# loss: tensor(43.2920, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(43.2920, device='cuda:1', grad_fn=<NllLossBackward0>)
# 6
# loss: tensor(43.4287, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(43.4287, device='cuda:1', grad_fn=<NllLossBackward0>)
# 7
# loss: tensor(45.7403, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(45.7403, device='cuda:1', grad_fn=<NllLossBackward0>)
# 8
# loss: tensor(33.4848, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(33.4848, device='cuda:1', grad_fn=<NllLossBackward0>)
# 9
# loss: tensor(37.5283, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(37.5283, device='cuda:1', grad_fn=<NllLossBackward0>)
# 10
# loss: tensor(32.5502, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(32.5502, device='cuda:1', grad_fn=<NllLossBackward0>)
# 11
# loss: tensor(26.7068, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(26.7068, device='cuda:1', grad_fn=<NllLossBackward0>)
# 12
# loss: tensor(37.1487, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(37.1487, device='cuda:1', grad_fn=<NllLossBackward0>)
# 13
# loss: tensor(28.6879, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(28.6879, device='cuda:1', grad_fn=<NllLossBackward0>)
# 14
# loss: tensor(31.5784, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(31.5784, device='cuda:1', grad_fn=<NllLossBackward0>)
# 15
# loss: tensor(31.4319, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(31.4319, device='cuda:1', grad_fn=<NllLossBackward0>)
# 16
# loss: tensor(27.8872, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(27.8872, device='cuda:1', grad_fn=<NllLossBackward0>)
# 17
# loss: tensor(25.4707, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(25.4707, device='cuda:1', grad_fn=<NllLossBackward0>)
# 18
# loss: tensor(16.4947, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(16.4947, device='cuda:1', grad_fn=<NllLossBackward0>)
# 19
# loss: tensor(25.6267, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(25.6267, device='cuda:1', grad_fn=<NllLossBackward0>)
# 20
# loss: tensor(22.8228, device='cuda:1', grad_fn=<AddBackward0>)
# negative_log_likelihood: tensor(22.8228, device='cuda:1', grad_fn=<NllLossBackward0>)
# Component 0 Accuracy: 9165.0/10000
# Component 1 Accuracy: 9147.0/10000
# Component 2 Accuracy: 9117.0/10000
# Component 3 Accuracy: 9158.0/10000
# Component 4 Accuracy: 9123.0/10000
# Component 5 Accuracy: 9119.0/10000
# Component 6 Accuracy: 9139.0/10000
# Component 7 Accuracy: 9140.0/10000
# Component 8 Accuracy: 9150.0/10000
# Component 9 Accuracy: 9138.0/10000
# Posterior Mean Accuracy: 9213.0/10000
# Ensemble Accuracy: 9197/10000
# vMF 10+20+20 epoch NII
# NIIvMF loss curve, 50 epoch Vision
# NIIvMF weight mu average norm per epoch Vision
